# %%
import boto3
import os
from botocore import UNSIGNED
from botocore.config import Config

# Public bucket, so we use an unsigned/anonymous client
s3 = boto3.client("s3", config=Config(signature_version=UNSIGNED))

bucket = "dsan6000-wikipedia"
prefix = "hourly_parquet/"

os.makedirs("data", exist_ok=True)

response = s3.list_objects_v2(Bucket=bucket, Prefix=prefix)
for obj in response.get("Contents", []):
    key = obj["Key"]
    if key.endswith(".parquet"):
        filename = os.path.basename(key)
        s3.download_file(bucket, key, os.path.join("data", filename))
        print(f"Downloaded {key}")
# Out:
# Downloaded hourly_parquet/20260901_040000.parquet
# Downloaded hourly_parquet/20260901_050000.parquet
# Downloaded hourly_parquet/20260901_060000.parquet
# Downloaded hourly_parquet/20260901_070000.parquet
# Downloaded hourly_parquet/20260901_080000.parquet
# Downloaded hourly_parquet/20260901_090000.parquet
# Downloaded hourly_parquet/20260901_100000.parquet
# Downloaded hourly_parquet/20260901_110000.parquet
# Downloaded hourly_parquet/20260901_120000.parquet
# Downloaded hourly_parquet/20260901_130000.parquet
# Downloaded hourly_parquet/20260901_140000.parquet
# Downloaded hourly_parquet/20260901_150000.parquet
# Downloaded hourly_parquet/20260901_160000.parquet
# Downloaded hourly_parquet/20260901_170000.parquet
# Downloaded hourly_parquet/20260901_180000.parquet
# Downloaded hourly_parquet/20260901_190000.parquet
# Downloaded hourly_parquet/20260901_200000.parquet
# Downloaded hourly_parquet/20260901_210000.parquet
# Downloaded hourly_parquet/20260901_220000.parquet
# Downloaded hourly_parquet/20260901_230000.parquet
# Downloaded hourly_parquet/20260902_000000.parquet
# Downloaded hourly_parquet/20260902_010000.parquet
# Downloaded hourly_parquet/20260902_020000.parquet
# Downloaded hourly_parquet/20260902_030000.parquet
